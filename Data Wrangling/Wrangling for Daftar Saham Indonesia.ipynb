# %% [markdown]
# ### Mohamad Ibnu Fajar Maulana
# ### 21083010106
# ### Data Wrangling
# ### Daftar Saham Indonesia

# %% [markdown]
# ### Load Dataset

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\gaming 3\anaconda3\lib\site-packages (2.0.1)

# %%
import pandas as pd
df = pd.read_csv("./DaftarSaham.csv")
df
# Out:
#      Code                            Name ListingDate       Shares  \
# 0    AALI         Astra Agro Lestari Tbk.  1997-12-09   1924688333
# 1    ABBA               Mahaka Media Tbk.  2002-04-03   3935892857
# 2    ABDA    Asuransi Bina Dana Arta Tbk.  1989-07-06    620806680
# 3    ABMM              ABM Investama Tbk.  2011-12-06   2753165000
# 4    ACES     Ace Hardware Indonesia Tbk.  2007-11-06  17150000000
# ..    ...                             ...         ...          ...
# 805  YULE  Yulie Sekuritas Indonesia Tbk.  2004-12-10   1785000000
# 806  ZBRA       Dosni Roha Indonesia Tbk.  1991-08-01   2510706263
# 807  ZINC          Kapuas Prima Coal Tbk.  2017-10-16  25250000000
# 808  ZONE              Mega Perintis Tbk.  2018-12-12    870171478
# 809  ZYRX    Zyrexindo Mandiri Buana Tbk.  2021-03-30   1333333350
#
#      ListingBoard                  Sector  LastPrice     MarketCap  \
# 0           Utama  Consumer Non-Cyclicals     8250.0  1.587868e+13
# 1    Pengembangan      Consumer Cyclicals      214.0  8.422811e+11
# 2    Pengembangan              Financials     6025.0  3.740360e+12
# 3           Utama             Industrials     3960.0  1.090253e+13
# 4           Utama      Consumer Cyclicals      610.0  1.046150e+13
# ..            ...                     ...        ...           ...
# 805  Pengembangan              Financials     2100.0  3.748500e+12
# 806  Pengembangan             Industrials      570.0  1.431103e+12
# 807  Pengembangan         Basic Materials       71.0  1.792750e+12
# 808  Pengembangan      Consumer Cyclicals     1045.0  9.093292e+11
# 809  Pengembangan              Technology      474.0  6.320000e+11
#
#        MinutesFirstAdded   MinutesLastUpdated     HourlyFirstAdded  \
# 0    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 1    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 2    2021-11-01 09:00:00  2022-09-23 15:59:00  2020-04-16 09:00:00
# 3    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 4    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# ..                   ...                  ...                  ...
# 805  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 806  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 807  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 808  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 809  2021-11-01 09:00:00  2022-09-30 15:59:00  2021-03-30 09:00:00
#
#        HourlyLastUpdated DailyFirstAdded DailyLastUpdated
# 0    2022-09-30 16:00:00      2001-04-16       2022-09-30
# 1    2022-09-30 16:00:00      2002-04-03       2022-09-30
# 2    2022-09-23 16:00:00      2001-04-16       2022-09-30
# 3    2022-09-30 16:00:00      2011-12-06       2022-09-30
# 4    2022-09-30 16:00:00      2007-11-06       2022-09-30
# ..                   ...             ...              ...
# 805  2022-09-30 16:00:00      2004-12-10       2022-09-30
# 806  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 807  2022-09-30 16:00:00      2017-10-16       2022-09-30
# 808  2022-09-30 16:00:00      2018-12-12       2022-09-30
# 809  2022-09-30 16:00:00      2021-03-30       2022-09-30
#
# [810 rows x 14 columns]

# %% [markdown]
# ### Menemukan Missing Value

# %%
#Memeriksa missing value setiap variabel
df.isnull().any()
# Out:
# Code                  False
# Name                  False
# ListingDate           False
# Shares                False
# ListingBoard          False
# Sector                False
# LastPrice              True
# MarketCap              True
# MinutesFirstAdded      True
# MinutesLastUpdated     True
# HourlyFirstAdded       True
# HourlyLastUpdated      True
# DailyFirstAdded        True
# DailyLastUpdated       True
# dtype: bool

# %%
for i in df.columns:
    miss = df[i].isnull().sum()
    if miss>0:
        print('\033[1m', '\33[31m')
        print("{} terdapat {} missing value(s)".format(i,miss))
    else:
        print('\033[1m', '\33[34m')
        print("{} tidak terdapat missing value!".format(i))
# Out:
#
# Code tidak terdapat missing value!
#
# Name tidak terdapat missing value!
#
# ListingDate tidak terdapat missing value!
#
# Shares tidak terdapat missing value!
#
# ListingBoard tidak terdapat missing value!
#
# Sector tidak terdapat missing value!
#
# LastPrice terdapat 45 missing value(s)
#
# MarketCap terdapat 45 missing value(s)
#
# MinutesFirstAdded terdapat 45 missing value(s)
#
# MinutesLastUpdated terdapat 45 missing value(s)
#
# HourlyFirstAdded terdapat 23 missing value(s)
#
# HourlyLastUpdated terdapat 23 missing value(s)
#
# DailyFirstAdded terdapat 5 missing value(s)
#
# DailyLastUpdated terdapat 5 missing value(s)

# %%
#Drop missing value rows using dropna() function
#Read the data
df = df.dropna()
df
# Out:
#      Code                            Name ListingDate       Shares  \
# 0    AALI         Astra Agro Lestari Tbk.  1997-12-09   1924688333
# 1    ABBA               Mahaka Media Tbk.  2002-04-03   3935892857
# 2    ABDA    Asuransi Bina Dana Arta Tbk.  1989-07-06    620806680
# 3    ABMM              ABM Investama Tbk.  2011-12-06   2753165000
# 4    ACES     Ace Hardware Indonesia Tbk.  2007-11-06  17150000000
# ..    ...                             ...         ...          ...
# 805  YULE  Yulie Sekuritas Indonesia Tbk.  2004-12-10   1785000000
# 806  ZBRA       Dosni Roha Indonesia Tbk.  1991-08-01   2510706263
# 807  ZINC          Kapuas Prima Coal Tbk.  2017-10-16  25250000000
# 808  ZONE              Mega Perintis Tbk.  2018-12-12    870171478
# 809  ZYRX    Zyrexindo Mandiri Buana Tbk.  2021-03-30   1333333350
#
#      ListingBoard                  Sector  LastPrice     MarketCap  \
# 0           Utama  Consumer Non-Cyclicals     8250.0  1.587868e+13
# 1    Pengembangan      Consumer Cyclicals      214.0  8.422811e+11
# 2    Pengembangan              Financials     6025.0  3.740360e+12
# 3           Utama             Industrials     3960.0  1.090253e+13
# 4           Utama      Consumer Cyclicals      610.0  1.046150e+13
# ..            ...                     ...        ...           ...
# 805  Pengembangan              Financials     2100.0  3.748500e+12
# 806  Pengembangan             Industrials      570.0  1.431103e+12
# 807  Pengembangan         Basic Materials       71.0  1.792750e+12
# 808  Pengembangan      Consumer Cyclicals     1045.0  9.093292e+11
# 809  Pengembangan              Technology      474.0  6.320000e+11
#
#        MinutesFirstAdded   MinutesLastUpdated     HourlyFirstAdded  \
# 0    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 1    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 2    2021-11-01 09:00:00  2022-09-23 15:59:00  2020-04-16 09:00:00
# 3    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 4    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# ..                   ...                  ...                  ...
# 805  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 806  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 807  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 808  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 809  2021-11-01 09:00:00  2022-09-30 15:59:00  2021-03-30 09:00:00
#
#        HourlyLastUpdated DailyFirstAdded DailyLastUpdated
# 0    2022-09-30 16:00:00      2001-04-16       2022-09-30
# 1    2022-09-30 16:00:00      2002-04-03       2022-09-30
# 2    2022-09-23 16:00:00      2001-04-16       2022-09-30
# 3    2022-09-30 16:00:00      2011-12-06       2022-09-30
# 4    2022-09-30 16:00:00      2007-11-06       2022-09-30
# ..                   ...             ...              ...
# 805  2022-09-30 16:00:00      2004-12-10       2022-09-30
# 806  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 807  2022-09-30 16:00:00      2017-10-16       2022-09-30
# 808  2022-09-30 16:00:00      2018-12-12       2022-09-30
# 809  2022-09-30 16:00:00      2021-03-30       2022-09-30
#
# [765 rows x 14 columns]

# %% [markdown]
# ### Melakukan Subsetting pada Dataset

# %%
df_subset = df.loc[
 [i for i in range(0,5)],
    ['Code','Name','ListingDate','Shares','LastPrice', 'MarketCap']]
df_subset
# Out:
#    Code                          Name ListingDate       Shares  LastPrice  \
# 0  AALI       Astra Agro Lestari Tbk.  1997-12-09   1924688333     8250.0
# 1  ABBA             Mahaka Media Tbk.  2002-04-03   3935892857      214.0
# 2  ABDA  Asuransi Bina Dana Arta Tbk.  1989-07-06    620806680     6025.0
# 3  ABMM            ABM Investama Tbk.  2011-12-06   2753165000     3960.0
# 4  ACES   Ace Hardware Indonesia Tbk.  2007-11-06  17150000000      610.0
#
#       MarketCap
# 0  1.587868e+13
# 1  8.422811e+11
# 2  3.740360e+12
# 3  1.090253e+13
# 4  1.046150e+13

# %%
df_subset = df.loc[
 [i for i in range(0, 48)],
    ['LastPrice', 'MarketCap']]
df_subset.describe()
# Out:
#          LastPrice     MarketCap
# count    48.000000  4.800000e+01
# mean   1389.166667  1.054186e+13
# std    2154.504508  2.525972e+13
# min      50.000000  5.324000e+10
# 25%     179.750000  3.835330e+11
# 50%     356.000000  1.805281e+12
# 75%    1421.250000  7.479988e+12
# max    8300.000000  1.266644e+14

# %%
import matplotlib as plt
boxplot = df_subset.boxplot()

# %% [markdown]
# ## Menemukan outliers

# %%
import pandas as pd

# Load data from CSV file
df = pd.read_csv('DaftarSaham.csv')

# Define the column(s) to check for outlier
column = 'LastPrice'

# Calculate IQR for the selected column
q1 = df[column].quantile(0.15)
q3 = df[column].quantile(0.85)
iqr = q3 - q1

# Define upper and lower limits to identify outliers
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# Find the outlier values
outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]

# Print the outlier values
outliers
# Out:
#      Code                            Name ListingDate        Shares  \
# 0    AALI         Astra Agro Lestari Tbk.  1997-12-09    1924688333
# 2    ABDA    Asuransi Bina Dana Arta Tbk.  1989-07-06     620806680
# 7    ADES  Akasha Wira International Tbk.  1994-06-13     589896800
# 9    ADMF  Adira Dinamika Multi Finance T  2004-03-31    1000000000
# 53   ARTO                  Bank Jago Tbk.  2016-01-12   13717687500
# 58   ASII        Astra International Tbk.  1990-04-04   40483553140
# 82   BBCA          Bank Central Asia Tbk.  2000-05-31  122042299500
# 87   BBNI  Bank Negara Indonesia (Persero  1996-11-25   18462169893
# 127  BMRI     Bank Mandiri (Persero) Tbk.  2003-07-14   46199999998
# 141  BPII  Batavia Prosperindo Internasio  2014-07-08     562224662
# 143  BRAM                Indo Kordsa Tbk.  1990-09-05     450000000
# 167  BYAN            Bayan Resources Tbk.  2008-08-12    3333333500
# 197  CPIN  Charoen Pokphand Indonesia Tbk  1991-03-18   16398000000
# 211  DCII              DCI Indonesia Tbk.  2021-01-06    2383745900
# 236  DSSA     Dian Swastatika Sentosa Tbk  2009-12-10     770552320
# 244  EDGE               Indointernet Tbk.  2021-02-08     404050000
# 268  FASW         Fajar Surya Wisesa Tbk.  1994-12-19    2477888787
# 272  FISH             FKS Multi Agro Tbk.  2002-01-18     480000000
# 286  GEMS        Golden Energy Mines Tbk.  2011-11-17    5882353000
# 287  GGRM               Gudang Garam Tbk.  1990-08-27    1924088000
# 295  GMTD  Gowa Makassar Tourism Developm  2000-12-11     101538000
# 317  HEXA         Hexindo Adiperkasa Tbk.  1995-02-13     840000000
# 332  IBST      Inti Bangun Sejahtera Tbk.  2012-08-31    1350904927
# 333  ICBP  Indofood CBP Sukses Makmur Tbk  2010-10-07   11661908000
# 351  INCO             Vale Indonesia Tbk.  1990-05-16    9936338720
# 352  INDF     Indofood Sukses Makmur Tbk.  1994-07-14    8780426500
# 354  INDR       Indo-Rama Synthetics Tbk.  1990-08-03     654351707
# 358  INKP    Indah Kiat Pulp & Paper Tbk.  1990-07-16    5470982941
# 366  INTP  Indocement Tunggal Prakarsa Tb  1989-12-05    3681231699
# 374  ISAT                    Indosat Tbk.  1994-10-19    8062702740
# 378  ITMG     Indo Tambangraya Megah Tbk.  2007-12-18    1129925000
# 438  LIFE  Asuransi Jiwa Sinarmas MSIG Tb  2019-07-09    2100000000
# 468  MBAP       Mitrabara Adiperdana Tbk.  2014-07-10    1227271952
# 471  MCAS           M Cash Integrasi Tbk.  2017-11-01     867933300
# 472  MCOL      Prima Andalan Mandiri Tbk.  2021-09-07    3555560000
# 481  MEGA                  Bank Mega Tbk.  2000-04-17   11623514905
# 496  MKPI      Metropolitan Kentjana Tbk.  2009-07-10     948194000
# 497  MLBI    Multi Bintang Indonesia Tbk.  1981-12-15    2107000000
# 532  NFCX              NFC Indonesia Tbk.  2018-07-12     666667500
# 625  RDTX                Roda Vivatex Tbk  1990-05-14     268800000
# 648  SCCO  Supreme Cable Manufacturing &   1982-07-20     205583400
# 651  SCPI   Organon Pharma Indonesia Tbk.  1990-06-08       3600000
# 678  SMGR  Semen Indonesia (Persero) Tbk.  1991-07-08    5931520000
# 681  SMMA        Sinarmas Multiartha Tbk.  1995-07-05    6367664717
# 689  SOHO         Soho Global Health Tbk.  2020-09-08    1269168239
# 705  STTP                Siantar Top Tbk.  1996-12-16    1310000000
# 708  SUPR       Solusi Tunas Pratama Tbk.  2011-10-11    1137579698
# 722  TCID           Mandom Indonesia Tbk.  1993-09-30     201066667
# 723  TCPI          Transcoal Pacific Tbk.  2018-07-06    5000000000
# 726  TECH   Indosterling Technomedia Tbk.  2020-06-04    1256300000
# 730  TGKA           Tigaraksa Satria Tbk.  1990-06-11     918492750
# 736  TKIM  Pabrik Kertas Tjiwi Kimia Tbk.  1990-04-03    3113223570
# 770  UNIC        Unggul Indah Cahaya Tbk.  1989-11-06     383331363
# 774  UNTR            United Tractors Tbk.  1989-09-19    3730135136
#
#      ListingBoard                    Sector  LastPrice     MarketCap  \
# 0           Utama    Consumer Non-Cyclicals     8250.0  1.587868e+13
# 2    Pengembangan                Financials     6025.0  3.740360e+12
# 7    Pengembangan    Consumer Non-Cyclicals     7175.0  4.232510e+12
# 9           Utama                Financials     8300.0  8.300000e+12
# 53   Pengembangan                Financials     6600.0  9.053674e+13
# 58          Utama               Industrials     6625.0  2.682035e+14
# 82          Utama                Financials     8550.0  1.043462e+15
# 87          Utama                Financials     8975.0  1.656980e+14
# 127         Utama                Financials     9425.0  4.354350e+14
# 141  Pengembangan                Financials    11500.0  6.465584e+12
# 143         Utama        Consumer Cyclicals     8300.0  3.735000e+12
# 167         Utama                    Energy    67000.0  2.233333e+14
# 197         Utama    Consumer Non-Cyclicals     5650.0  9.264870e+13
# 211  Pengembangan                Technology    36750.0  8.760266e+13
# 236         Utama                    Energy    38000.0  2.928099e+13
# 244  Pengembangan                Technology    21625.0  8.737581e+12
# 268         Utama           Basic Materials     6250.0  1.548680e+13
# 272  Pengembangan    Consumer Non-Cyclicals     7050.0  3.384000e+12
# 286         Utama                    Energy     7100.0  4.176471e+13
# 287         Utama    Consumer Non-Cyclicals    22925.0  4.410972e+13
# 295  Pengembangan  Properties & Real Estate    14525.0  1.474839e+12
# 317         Utama               Industrials     6500.0  5.460000e+12
# 332         Utama           Infrastructures     7000.0  9.456334e+12
# 333         Utama    Consumer Non-Cyclicals     8650.0  1.008755e+14
# 351         Utama           Basic Materials     6400.0  6.359257e+13
# 352         Utama    Consumer Non-Cyclicals     6025.0  5.290207e+13
# 354         Utama        Consumer Cyclicals     6875.0  4.498668e+12
# 358         Utama           Basic Materials     9050.0  4.951240e+13
# 366         Utama           Basic Materials     9500.0  3.497170e+13
# 374         Utama           Infrastructures     7250.0  5.845459e+13
# 378         Utama                    Energy    41425.0  4.680714e+13
# 438         Utama                Financials     5900.0  1.239000e+13
# 468  Pengembangan                    Energy     8700.0  1.067727e+13
# 471  Pengembangan                Technology    11400.0  9.894440e+12
# 472         Utama                    Energy     7050.0  2.506670e+13
# 481         Utama                Financials     5750.0  6.683521e+13
# 496  Pengembangan  Properties & Real Estate    22950.0  2.176105e+13
# 497         Utama    Consumer Non-Cyclicals     8625.0  1.817288e+13
# 532  Pengembangan                Technology    12200.0  8.133344e+12
# 625         Utama  Properties & Real Estate     8625.0  2.318400e+12
# 648         Utama               Industrials     8100.0  1.665226e+12
# 651  Pengembangan                Healthcare    29000.0  1.044000e+11
# 678         Utama           Basic Materials     7475.0  4.433811e+13
# 681         Utama                Financials    12300.0  7.832228e+13
# 689         Utama                Healthcare     5750.0  7.297717e+12
# 705  Pengembangan    Consumer Non-Cyclicals     7650.0  1.002150e+13
# 708  Pengembangan           Infrastructures    38675.0  4.399589e+13
# 722         Utama    Consumer Non-Cyclicals     6100.0  1.226507e+12
# 723  Pengembangan                    Energy     9100.0  4.550000e+13
# 726  Pengembangan                Technology     5900.0  7.412170e+12
# 730  Pengembangan    Consumer Non-Cyclicals     8300.0  7.623490e+12
# 736         Utama           Basic Materials     7375.0  2.296002e+13
# 770         Utama           Basic Materials    10975.0  4.207062e+12
# 774         Utama               Industrials    32825.0  1.224417e+14
#
#        MinutesFirstAdded   MinutesLastUpdated     HourlyFirstAdded  \
# 0    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 2    2021-11-01 09:00:00  2022-09-23 15:59:00  2020-04-16 09:00:00
# 7    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 9    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 53   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 58   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 82   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 87   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 127  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 141  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 143  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 167  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 197  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 211  2021-11-01 09:00:00  2022-09-30 15:59:00  2021-01-06 09:00:00
# 236  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 244  2021-11-01 09:00:00  2022-09-30 15:59:00  2021-02-08 09:00:00
# 268  2021-12-27 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 272  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 286  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 287  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 295  2021-11-15 09:00:00  2022-06-17 15:59:00  2020-04-16 09:00:00
# 317  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 332  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 333  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 351  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 352  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 354  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 358  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 366  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 374  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 378  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 438  2021-11-01 09:00:00  2022-09-23 15:59:00  2020-04-16 09:00:00
# 468  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 471  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 472  2021-11-01 09:00:00  2022-09-30 15:59:00  2021-09-07 09:00:00
# 481  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 496  2022-01-17 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 497  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 532  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 625  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 648  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 651  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 678  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 681  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 689  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-09-08 09:00:00
# 705  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 708  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 722  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 723  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 726  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-06-04 09:00:00
# 730  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 736  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 770  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 774  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
#
#        HourlyLastUpdated DailyFirstAdded DailyLastUpdated
# 0    2022-09-30 16:00:00      2001-04-16       2022-09-30
# 2    2022-09-23 16:00:00      2001-04-16       2022-09-30
# 7    2022-09-30 16:00:00      2001-04-16       2022-09-30
# 9    2022-09-30 16:00:00      2004-03-31       2022-09-30
# 53   2022-09-30 16:00:00      2016-01-12       2022-09-30
# 58   2022-09-30 16:00:00      2001-04-16       2022-09-30
# 82   2022-09-30 16:00:00      2001-04-16       2022-09-30
# 87   2022-09-30 16:00:00      2001-04-16       2022-09-30
# 127  2022-09-30 16:00:00      2003-07-14       2022-09-30
# 141  2022-09-30 16:00:00      2014-07-08       2022-09-30
# 143  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 167  2022-09-30 16:00:00      2008-08-12       2022-09-30
# 197  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 211  2022-09-30 16:00:00      2021-01-06       2022-09-30
# 236  2022-09-30 16:00:00      2009-12-10       2022-09-30
# 244  2022-09-30 16:00:00      2021-02-08       2022-09-30
# 268  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 272  2022-09-30 16:00:00      2002-01-18       2022-09-30
# 286  2022-09-30 16:00:00      2011-11-17       2022-09-30
# 287  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 295  2022-06-17 16:00:00      2001-04-16       2022-09-30
# 317  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 332  2022-09-30 16:00:00      2012-08-31       2022-09-30
# 333  2022-09-30 16:00:00      2010-10-07       2022-09-30
# 351  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 352  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 354  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 358  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 366  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 374  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 378  2022-09-30 16:00:00      2007-12-18       2022-09-30
# 438  2022-09-23 16:00:00      2019-07-09       2022-09-30
# 468  2022-09-30 16:00:00      2014-07-10       2022-09-30
# 471  2022-09-30 16:00:00      2017-11-01       2022-09-30
# 472  2022-09-30 16:00:00      2021-09-07       2022-09-30
# 481  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 496  2022-09-30 16:00:00      2009-07-10       2022-09-30
# 497  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 532  2022-09-30 16:00:00      2018-07-12       2022-09-30
# 625  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 648  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 651  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 678  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 681  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 689  2022-09-30 16:00:00      2020-09-08       2022-09-30
# 705  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 708  2022-09-30 16:00:00      2011-10-11       2022-09-30
# 722  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 723  2022-09-30 16:00:00      2018-07-06       2022-09-30
# 726  2022-09-30 16:00:00      2020-06-04       2022-09-30
# 730  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 736  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 770  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 774  2022-09-30 16:00:00      2001-04-16       2022-09-30

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from CSV file
df = pd.read_csv('DaftarSaham.csv')

# Define the column(s) to check for outlier
column = 'LastPrice'

# Calculate IQR for the selected column
q1 = df[column].quantile(0.15)
q3 = df[column].quantile(0.85)
iqr = q3 - q1

# Define upper and lower limits to identify outliers
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# Find the outlier values
outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]

# Create a boxplot with outliers
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot(df[column], showfliers=True)

# Add a red marker for each outlier value
ax.plot(list(outliers.index), outliers[column], 'ro', markersize=5)

# Set the title and labels
ax.set_title("LastPrice with Outliers")
ax.set_xlabel("Features")
ax.set_ylabel("Values")

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Show the plot
plt.show()

# %%
import pandas as pd

# Load data from CSV file
df = pd.read_csv('DaftarSaham.csv')

# Define the column(s) to check for outlier
column = 'MarketCap'

# Calculate IQR for the selected column
q1 = df[column].quantile(0.25)
q3 = df[column].quantile(0.75)
iqr = q3 - q1

# Define upper and lower limits to identify outliers
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# Find the outlier values
outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]

# Print the outlier values
outliers
# Out:
#      Code                            Name ListingDate       Shares  \
# 0    AALI         Astra Agro Lestari Tbk.  1997-12-09   1924688333
# 11   ADMR   Adaro Minerals Indonesia Tbk.  2022-01-03  40882331500
# 12   ADRO     Adaro Energy Indonesia Tbk.  2008-07-16  31985962000
# 15   AGRO        Bank Raya Indonesia Tbk.  2003-08-08  22520054593
# 22   AKRA             AKR Corporindo Tbk.  1994-10-03  20073474600
# ..    ...                             ...         ...          ...
# 749  TPIA  Chandra Asri Petrochemical Tbk  2008-05-26  21627886273
# 769  ULTJ  Ultra Jaya Milk Industry & Tra  1990-07-02  11553528000
# 774  UNTR            United Tractors Tbk.  1989-09-19   3730135136
# 775  UNVR         Unilever Indonesia Tbk.  1982-01-11  38150000000
# 801  WSKT    Waskita Karya (Persero) Tbk.  2012-12-19  28806807016
#
#      ListingBoard                  Sector  LastPrice     MarketCap  \
# 0           Utama  Consumer Non-Cyclicals     8250.0  1.587868e+13
# 11   Pengembangan                  Energy     1800.0  7.358820e+13
# 12          Utama                  Energy     3960.0  1.266644e+14
# 15          Utama              Financials      550.0  1.238603e+13
# 22          Utama                  Energy     1350.0  2.709919e+13
# ..            ...                     ...        ...           ...
# 749  Pengembangan         Basic Materials     2400.0  5.190693e+13
# 769         Utama  Consumer Non-Cyclicals     1390.0  1.605940e+13
# 774         Utama             Industrials    32825.0  1.224417e+14
# 775         Utama  Consumer Non-Cyclicals     4830.0  1.842645e+14
# 801         Utama         Infrastructures      505.0  1.454744e+13
#
#        MinutesFirstAdded   MinutesLastUpdated     HourlyFirstAdded  \
# 0    2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 11   2022-01-03 09:00:00  2022-09-30 15:59:00  2022-01-03 09:00:00
# 12   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 15   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 22   2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# ..                   ...                  ...                  ...
# 749  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 769  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 774  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 775  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
# 801  2021-11-01 09:00:00  2022-09-30 15:59:00  2020-04-16 09:00:00
#
#        HourlyLastUpdated DailyFirstAdded DailyLastUpdated
# 0    2022-09-30 16:00:00      2001-04-16       2022-09-30
# 11   2022-09-30 16:00:00      2022-01-03       2022-09-30
# 12   2022-09-30 16:00:00      2008-07-16       2022-09-30
# 15   2022-09-30 16:00:00      2003-08-08       2022-09-30
# 22   2022-09-30 16:00:00      2001-04-16       2022-09-30
# ..                   ...             ...              ...
# 749  2022-09-30 16:00:00      2008-05-26       2022-09-30
# 769  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 774  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 775  2022-09-30 16:00:00      2001-04-16       2022-09-30
# 801  2022-09-30 16:00:00      2012-12-19       2022-09-30
#
# [115 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from CSV file
df = pd.read_csv('DaftarSaham.csv')

# Define the column(s) to check for outlier
column = 'MarketCap'

# Calculate IQR for the selected column
q1 = df[column].quantile(0.25)
q3 = df[column].quantile(0.75)
iqr = q3 - q1

# Define upper and lower limits to identify outliers
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# Find the outlier values
outliers = df[(df[column] < lower_limit) | (df[column] > upper_limit)]

# Create a boxplot with outliers
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot(df[column], showfliers=True)

# Add a red marker for each outlier value
ax.plot(list(outliers.index), outliers[column], 'ro', markersize=5)

# Set the title and labels
ax.set_title("MarketCap with Outliers")
ax.set_xlabel("Features")
ax.set_ylabel("Values")

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Show the plot
plt.show()

# %% [markdown]
# ### Group By Method

# %%
df_subset = df.loc[[i for i in range (10)],\
                   ['ListingBoard','Sector','LastPrice']]
df_subset
# Out:
#    ListingBoard                    Sector  LastPrice
# 0         Utama    Consumer Non-Cyclicals     8250.0
# 1  Pengembangan        Consumer Cyclicals      214.0
# 2  Pengembangan                Financials     6025.0
# 3         Utama               Industrials     3960.0
# 4         Utama        Consumer Cyclicals      610.0
# 5         Utama           Infrastructures      176.0
# 6         Utama  Properties & Real Estate       81.0
# 7  Pengembangan    Consumer Non-Cyclicals     7175.0
# 8         Utama           Infrastructures      715.0
# 9         Utama                Financials     8300.0

# %%
bySector = df_subset.groupby('Sector')
bySector

# %%
print('\033[1m', '\33[32m')
print(" Data kelompok berdasarkan sektor dan harga rata rata penutupan saham")
bySector.mean()
# Out:
#
#  Data kelompok berdasarkan sektor dan harga rata rata penutupan saham
#                           LastPrice
# Sector
# Consumer Cyclicals            412.0
# Consumer Non-Cyclicals       7712.5
# Financials                   7162.5
# Industrials                  3960.0
# Infrastructures               445.5
# Properties & Real Estate       81.0

# %%
print('\033[1m', '\33[32m')
print("Data kelompok berdasarkan sektor dan total harga penutupan saham")
bySector.sum()
# Out:
#
# Data kelompok berdasarkan sektor dan total harga penutupan saham
#                           LastPrice
# Sector
# Consumer Cyclicals            824.0
# Consumer Non-Cyclicals      15425.0
# Financials                  14325.0
# Industrials                  3960.0
# Infrastructures               891.0
# Properties & Real Estate       81.0

# %%
pd.DataFrame(bySector.describe().loc['Financials'])
# Out:
#                   Financials
# LastPrice count     2.000000
#           mean   7162.500000
#           std    1608.667927
#           min    6025.000000
#           25%    6593.750000
#           50%    7162.500000
#           75%    7731.250000
#           max    8300.000000

# %%
df_subset.groupby('ListingBoard').describe()\
.loc[['Pengembangan','Utama']]
# Out:
#              LastPrice                                                   \
#                  count         mean          std    min     25%     50%
# ListingBoard
# Pengembangan       3.0  4471.333333  3731.526542  214.0  3119.5  6025.0
# Utama              7.0  3156.000000  3737.927456   81.0   393.0   715.0
#
#
#                  75%     max
# ListingBoard
# Pengembangan  6600.0  7175.0
# Utama         6105.0  8300.0

# %%
byNameSector=df.groupby(['Name','Sector'])
byNameSector.describe()['LastPrice']
# Out:
#                                                    count    mean  std     min  \
# Name                           Sector
# ABM Investama Tbk.             Industrials           1.0  3960.0  NaN  3960.0
# AKR Corporindo Tbk.            Energy                1.0  1350.0  NaN  1350.0
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals    1.0   610.0  NaN   610.0
# Ace Oldfields Tbk.             Industrials           1.0    80.0  NaN    80.0
# Acset Indonusa Tbk.            Infrastructures       1.0   176.0  NaN   176.0
# ...                                                  ...     ...  ...     ...
# XL Axiata Tbk.                 Infrastructures       1.0  2460.0  NaN  2460.0
# Yanaprima Hastapersada Tbk     Basic Materials       1.0   765.0  NaN   765.0
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    1.0    90.0  NaN    90.0
# Yulie Sekuritas Indonesia Tbk. Financials            1.0  2100.0  NaN  2100.0
# Zyrexindo Mandiri Buana Tbk.   Technology            1.0   474.0  NaN   474.0
#
#                                                       25%     50%     75%  \
# Name                           Sector
# ABM Investama Tbk.             Industrials         3960.0  3960.0  3960.0
# AKR Corporindo Tbk.            Energy              1350.0  1350.0  1350.0
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals   610.0   610.0   610.0
# Ace Oldfields Tbk.             Industrials           80.0    80.0    80.0
# Acset Indonusa Tbk.            Infrastructures      176.0   176.0   176.0
# ...                                                   ...     ...     ...
# XL Axiata Tbk.                 Infrastructures     2460.0  2460.0  2460.0
# Yanaprima Hastapersada Tbk     Basic Materials      765.0   765.0   765.0
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    90.0    90.0    90.0
# Yulie Sekuritas Indonesia Tbk. Financials          2100.0  2100.0  2100.0
# Zyrexindo Mandiri Buana Tbk.   Technology           474.0   474.0   474.0
#
#                                                       max
# Name                           Sector
# ABM Investama Tbk.             Industrials         3960.0
# AKR Corporindo Tbk.            Energy              1350.0
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals   610.0
# Ace Oldfields Tbk.             Industrials           80.0
# Acset Indonusa Tbk.            Infrastructures      176.0
# ...                                                   ...
# XL Axiata Tbk.                 Infrastructures     2460.0
# Yanaprima Hastapersada Tbk     Basic Materials      765.0
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    90.0
# Yulie Sekuritas Indonesia Tbk. Financials          2100.0
# Zyrexindo Mandiri Buana Tbk.   Technology           474.0
#
# [810 rows x 8 columns]

# %%
byNameSector = df.groupby(['Name','Sector'])
mean = byNameSector.describe()['LastPrice']['mean'].mean()
byNameSector.describe()['LastPrice'].fillna(mean)
# Out:
#                                                    count    mean          std  \
# Name                           Sector
# ABM Investama Tbk.             Industrials           1.0  3960.0  1591.681046
# AKR Corporindo Tbk.            Energy                1.0  1350.0  1591.681046
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals    1.0   610.0  1591.681046
# Ace Oldfields Tbk.             Industrials           1.0    80.0  1591.681046
# Acset Indonusa Tbk.            Infrastructures       1.0   176.0  1591.681046
# ...                                                  ...     ...          ...
# XL Axiata Tbk.                 Infrastructures       1.0  2460.0  1591.681046
# Yanaprima Hastapersada Tbk     Basic Materials       1.0   765.0  1591.681046
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    1.0    90.0  1591.681046
# Yulie Sekuritas Indonesia Tbk. Financials            1.0  2100.0  1591.681046
# Zyrexindo Mandiri Buana Tbk.   Technology            1.0   474.0  1591.681046
#
#                                                       min     25%     50%  \
# Name                           Sector
# ABM Investama Tbk.             Industrials         3960.0  3960.0  3960.0
# AKR Corporindo Tbk.            Energy              1350.0  1350.0  1350.0
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals   610.0   610.0   610.0
# Ace Oldfields Tbk.             Industrials           80.0    80.0    80.0
# Acset Indonusa Tbk.            Infrastructures      176.0   176.0   176.0
# ...                                                   ...     ...     ...
# XL Axiata Tbk.                 Infrastructures     2460.0  2460.0  2460.0
# Yanaprima Hastapersada Tbk     Basic Materials      765.0   765.0   765.0
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    90.0    90.0    90.0
# Yulie Sekuritas Indonesia Tbk. Financials          2100.0  2100.0  2100.0
# Zyrexindo Mandiri Buana Tbk.   Technology           474.0   474.0   474.0
#
#                                                       75%     max
# Name                           Sector
# ABM Investama Tbk.             Industrials         3960.0  3960.0
# AKR Corporindo Tbk.            Energy              1350.0  1350.0
# Ace Hardware Indonesia Tbk.    Consumer Cyclicals   610.0   610.0
# Ace Oldfields Tbk.             Industrials           80.0    80.0
# Acset Indonusa Tbk.            Infrastructures      176.0   176.0
# ...                                                   ...     ...
# XL Axiata Tbk.                 Infrastructures     2460.0  2460.0
# Yanaprima Hastapersada Tbk     Basic Materials      765.0   765.0
# Yelooo Integra Datanet Tbk.    Consumer Cyclicals    90.0    90.0
# Yulie Sekuritas Indonesia Tbk. Financials          2100.0  2100.0
# Zyrexindo Mandiri Buana Tbk.   Technology           474.0   474.0
#
# [810 rows x 8 columns]
